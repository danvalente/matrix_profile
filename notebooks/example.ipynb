# %%
from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat

# %%
plt.rcParams['figure.figsize'] = [16, 8]

# %%
import matrix_profile.mp as mp
reload(mp)
# Out:
# <module 'matrix_profile.mp' from '/Users/danielv/timeseries/matrix_profile/mp.py'>

# %%
t=np.arange(200)
x1 = np.random.rand(1000)
x2 = np.random.rand(1000)
x3 = np.random.rand(1000)
start = 300
y1 = 2 * np.sin(0.09 * t) + .3 * np.random.rand(200)
y2 = 2 * np.sin(0.09 * t) + .3 * np.random.rand(200)
y3 = 2 * np.sin(0.09 * t) + .3 * np.random.rand(200)
x1[start:start+len(y1)] = y1
x2[start:start+len(y2)] = y2
x3[start:start+len(y3)] = y3
z = np.concatenate((x1, x2, x3))

# %%
#x1 = np.random.rand(200)
#x2 = np.random.rand(200)

#y1 = 2 * np.ones(20) + .3 * np.random.rand(20)
#y2 = 2 * np.ones(20) + .3 * np.random.rand(20)

#start = 37
#x1[start:start+len(y1)] = y1
#x2[start:start+len(y2)] = y2

#z = np.concatenate((x1, x2))

# %%
plt.plot(z)

# %% [markdown]
# # MASS

# %%
mass = mp.mass(y1, z)

# %%
plt.plot(mass, 'k', z, 'r')

# %% [markdown]
# # STAMP

# %%
# %time profile, index = mp.stamp(z, m=200)
# Out:
# CPU times: user 1.15 s, sys: 9.78 ms, total: 1.16 s
# Wall time: 1.16 s

# %%
plt.plot(profile, 'k.-', z)

# %%
np.argmin(profile)
# Out:
# 299

# %% [markdown]
# # STOMP

# %%
# %time profile, index = mp.stomp(z, m=200)
# Out:
# CPU times: user 7.41 s, sys: 37.3 ms, total: 7.45 s
# Wall time: 7.45 s

# %%
plt.plot(profile, 'k.-', z)

# %%
np.argmin(profile)
# Out:
# 300
